# %%
if 5 > 2 : print("yes")
x = 5
print(type(x))
s = "this is a string"
print(type(s))
# Out:
# yes
# <class 'int'>
# <class 'str'>

# %%
name = "John"
id = 117
print(name, id) 
last_name = "Sally"
print(name + " " + last_name )
# Out:
# John 117
# John Sally

# %%
x = 11;
def f() :
    global x
    x = 12
    print(x);   

f()
print(x)
# Out:
# 12
# 12

# %%
my_dict = {
    "brand" : "Subaru",
    "model" : "WRX",
    "yeaer" : 2006
}

print(my_dict)

for x in my_dict : print(x)
# Out:
# {'brand': 'Subaru', 'model': 'WRX', 'yeaer': 2006}
# brand
# model
# yeaer

# %%
var = 3
f"string {var}"
# Out:
# 'string 3'

# %%
[i**2 for i in range(10)]
even_squares = [i**2 for i in range(10) if i % 2 == 0]
print(even_squares)
# Out:
# [0, 4, 16, 36, 64]

# %%
for it in my_dict.items() : print(it)
# Out:
# ('brand', 'Subaru')
# ('model', 'WRX')
# ('yeaer', 2006)

# %%
import random
import matplotlib.pyplot as plt
data = [random.random() * i for i in range(200)]

plt.plot(data)
plt.xlabel('Number')
plt.ylabel('Value')
plt.title('Title')
plt.legend()

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
for i in range(8) : print(random.random())
# Out:
# 0.7863002962685032
# 0.6834702576250898
# 0.7405919357029553
# 0.4415134301351218
# 0.6653764189564446
# 0.06467576021739208
# 0.272216817998007
# 0.6347878548933232

# %%
random.randint(2, 5)
# Out:
# 5
